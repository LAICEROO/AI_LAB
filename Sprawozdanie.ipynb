# %% [markdown]
# <a href="https://colab.research.google.com/github/LAICEROO/AI_LAB/blob/main/Sprawozdanie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SPRAWOZDANIE**

# %% [markdown]
# **Importujemy dane z pliku csv oraz tworzymy wykres**

# %%
import csv #biblioteka do obslugi plikow CSV
import matplotlib.pyplot as plt

#pobranie pliku CSV
# !wget bigbang.prz.edu.pl/si/birth_weight_vs_iq.csv

#wczytujemy plik CSV o podanej nazwie\
with open('birth_weight_vs_iq.csv') as csv_file:
    #ustawiamy znak rozdzielajacy wartosci w pliku
    #w tym przypadku to przecinek
    csv_reader = csv.reader(csv_file, delimiter=',')

    #tworzymy puste tablice do zapamietania
    #wagi urodzeniowej dziecka
    #to zbior wartosci x
    birth_weight=[]
    #wartosci IQ w wieku 5 lat
    #to zbior wartosci y
    iq_value=[]

    #odczytujemy plik CSV wiersz po wierszu
    for row in csv_reader:
      #w zmiennej row jest zapamietana zawartosc wiersza
      #w row[0] - zapamietana jest wartosc wagi (pierwsza kolumna)
      birth_weight.append( float(row[0]) )
      #w row[1] - zapamietany jest IQ (druga kolumna)
      iq_value.append( float(row[1]) )

#rysuhjemy wykres zeby sprawdzic czy import sie udal
plt.xlabel('Waga po urodzniu')
plt.ylabel('IQ dzicka')
plt.scatter(birth_weight, iq_value)
plt.title(" IQ dziecka vs Waga ")
# Out:
# --2023-12-13 14:43:47--  http://bigbang.prz.edu.pl/si/birth_weight_vs_iq.csv
# Resolving bigbang.prz.edu.pl (bigbang.prz.edu.pl)... 89.188.209.177
# Connecting to bigbang.prz.edu.pl (bigbang.prz.edu.pl)|89.188.209.177|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://bigbang.prz.edu.pl/si/birth_weight_vs_iq.csv [following]
# --2023-12-13 14:43:48--  https://bigbang.prz.edu.pl/si/birth_weight_vs_iq.csv
# Connecting to bigbang.prz.edu.pl (bigbang.prz.edu.pl)|89.188.209.177|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2929 (2.9K) [text/csv]
# Saving to: ‘birth_weight_vs_iq.csv.1’
#
# birth_weight_vs_iq. 100%[===================>]   2.86K  --.-KB/s    in 0s
#
# 2023-12-13 14:43:49 (25.8 MB/s) - ‘birth_weight_vs_iq.csv.1’ saved [2929/2929]
# Text(0.5, 1.0, ' IQ dziecka vs Waga ')

# %%
print(len(birth_weight))
print(len(iq_value))
# Out:
# 134
# 134

# %%
plt.xlabel('Waga dziecka')
plt.ylabel('IQ dziecka')
plt.scatter(birth_weight, iq_value, color="orange")
plt.title(" IQ dziecka vs Waga dziecka ")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Obliczenie optymalnej wartości parametru a z metody najmniejszych kwadratów

# %%
x = list(map(lambda x: x / 1000, birth_weight))
y = list(map(lambda x: x / 100,  iq_value ))

#tworzymy pusta liste xy zeby zapamietamy iloczyny x1*y1, x2*y2 itd w liscie xy
xy = []

for i in range(0, len(x)):
  xy.append( x[i]*y[i] )

#wyswietlamy zawartosc listy xy
print(xy)

#sumujemy ilocznyny, aby policzyc 1 czlon licznika we wzorze na a
suma_xy = sum(xy)
print(suma_xy)
# Out:
815, 0.9742017752309815, 0.9752759761829557, 0.9770112253592237, 0.9798206769720833, 0.9800410253904362, 0.9811152278270279, 0.9815559261483513, 0.9875879821017508, 0.9878083320047213, 0.988221486217019, 0.9888825329566953, 0.9891028828596659, 0.9901770852962575, 0.9910309378298786, 0.9921051387818527, 0.9936200395397677, 0.9938403879581207, 0.9964294896680098, 0.9966498395709803, 0.9968701879893332, 0.9968701879893332, 0.9972833436862485, 0.9975036921046014, 0.9979443904259249, 0.9998724453961376, 1.0011669962510823, 1.002268741312082, 1.002268741312082, 1.0024615471060268, 1.0037560979609714, 1.0041967962822949, 1.0057116970402098, 1.0063451996708606, 1.007446946216478, 1.007639750525805, 1.0078601004287755, 1.0085211471684519, 1.0093749997020731, 1.0098156980233965, 1.0098156980233965, 1.010036047926367, 1.0115234045752564, 1.013038303848554, 1.0132586537515245, 1.0149939029277923, 1.0149939029277923, 1.016288453782737, 1.0184368571713027, 1.0193182538139494, 1.0195110596078942, 1.020805610462839, 1.0229815579604302, 1.023394712172728, 1.023615060591081, 1.0259838138826172, 1.0262041623009701, 1.0262041623009701, 1.0290136139138297, 1.0290136139138297, 1.029674660653506, 1.0305285146717447, 1.0309692129930683, 1.0320434139450423, 1.0320434139450423, 1.0326769180603104, 1.0331176163816338, 1.033337964799987, 1.034191817333608, 1.0350456713518468, 1.03548636967317, 1.0363402222067912, 1.0365605706251442, 1.0370012689464676, 1.037221618849438, 1.0387365181227357, 1.0389293239166804]

# %%
#dane prawdziwe
plt.scatter(x, y, color="black")
#dane przewidywane
plt.xlabel('Waga dziecka')
plt.ylabel('IQ dziecka')

#plt.scatter(x, y_predicted, label="predicted", color="red" )
plt.plot(x, y_predicted, color="red", label="prediction")

plt.title(" IQ dziecka vs Waga dziecka ")
plt.legend()
plt.show()

# %%
from scipy import stats
from scipy.stats import chisquare
import statistics
import numpy as np

#tworzymy liste do przechowywania kwadratow roznic
roznica_y_ypred_do_kwadratu = []


for i in range(0, len(x)): #i przyjmie wartosci od 0 do 9
#append dodaje roznice yi - ypred_i podniesiona do kwadratu
  roznica_y_ypred_do_kwadratu.append( ( y_predicted[i] - y[i] )**2 )


#wyswietlamy wartosc bledu mse
mse = 1/n * sum(roznica_y_ypred_do_kwadratu)
print("MSE", mse)
# R_Squared
variance_y = np.var(y)
R_squared = 1 - (mse/variance_y)
print("R^2", R_squared)
# Chi_Squared
chi_squared = np.sum(np.square(np.divide(np.subtract(y,y_predicted),y_predicted)))

print("Chi-squared:", chi_squared)
# Out:
# MSE 0.02091336093365562
# R^2 0.0657382918490721
# Chi-squared: 2.9553070931144463

# %%
# porownanie
from sklearn.metrics import mean_squared_error, r2_score

# Mean Squared Error (MSE)
mse_compare = mean_squared_error(y, y_predicted)
print("Mean Squared Error (MSE):", mse_compare)

# R^2
r_squared_compare = r2_score(y, y_predicted )
print("R-squared (R^2):", r_squared_compare)
# Out:
# Mean Squared Error (MSE): 0.020913360933655617
# R-squared (R^2): 0.06573829184907232

# %%
from scipy.stats import chisquare


# chi-squared goodness-of-fit test
chi2_stat, p_value = chisquare(f_obs=y, f_exp=y_predicted)

#dane przewidywane
plt.xlabel('Waga dziecka')
plt.ylabel('IQ dziecka')

#plt.scatter(x, y_predicted, label="predicted", color="red" )
plt.plot(x, y_predicted, color="red", label="prediction")

plt.title("IQ dziecka vs Waga dziecka")
plt.legend()
plt.show()

# %% [markdown]
# Obliczyć wartość MSE dla wylosowanych wyżej wartości parametrów a i b

# %%
#tworzymy liste do przechowywania kwadratow roznic
roznica_y_ypred_do_kwadratu = []


for i in range(0, len(x)): #i przyjmie wartosci od 0 do 9
#append dodaje roznice yi - ypred_i podniesiona do kwadratu
  roznica_y_ypred_do_kwadratu.append( ( y_predicted[i] - y[i] )**2 )


#wyswietlamy wartosc bledu mse
mse = 1/n * sum(roznica_y_ypred_do_kwadratu)
print(mse)
# Out:
# 1.4447325468228454

# %% [markdown]
# Obliczyć pochodne dJ/da oraz dJ/db za pomocą pętli for, tak jak to robiono na poprzednich zajęciach. Możesz wykorzystać pętlę for do obliczania sumy iloczynów współrzędnych xi * yi.

# %%
# KROK 1 losowanie paramterow a i b
a = random.uniform(-1,1)
b = random.uniform(-1,1)
print('Parametry a i b maja wartosci',a,b)
# Out:
# Parametry a i b maja wartosci -0.9217176236353575 0.03928641532522681

# %%
n = len(x)
learning_rate = 0.001

listaa = [a]
listab = [b]
listaMSE = []

for i in range(0,10000):
  listaa.append(a)
  listab.append(b)
  # KROK 2 obliczenie aktualnej warosci cisninenia przewidywanego
  y_predicted = list(map(lambda iks: a * iks + b, x))

  # KROK3 Obliczenie pochodnych dJ_da oraz dJ_db
  roznica_ypred_y_razy_x = []

  roznica_y_ypred_do_kwadratu = []


  for i in range(0, len(x)): #i przyjmie wartosci od 0 do 9
  #append dodaje roznice ypred_i y_i
    roznica_ypred_y_razy_x.append( (y_predicted[i]-y[i])*x[i])
    roznica_y_ypred_do_kwadratu.append( ( (y_predicted[i] - y[i]) )**2 )

  mse = 1/n * sum(roznica_y_ypred_do_kwadratu)
  listaMSE.append(mse)

  dJ_da = 2/n * sum(roznica_ypred_y_razy_x)


  #dJ_db
  roznica_ypred_y = []
  #i przyjmie wartosci od 0 do 9
  for i in range(0, len(x)):
#append dodaje roznice ypred_i y_i
   roznica_ypred_y.append(y_predicted[i]-y[i])


  dJ_db = 2/n * sum(roznica_ypred_y)

  #KROK 4 atualizacja wartosci a i b
  a = a - learning_rate * dJ_da
  b = b - learning_rate * dJ_db

print('dJ_da= ',dJ_da, 'dJ_db= ', dJ_db, 'a= ',a, 'b= ',  b)
print('Zmiana a ', listaa[:100])
print('Zmiana b', listab[:100])
print('Zmiana MSE', listaMSE[:100])
# Out:
# dJ_da=  -0.0025748594704974735 dJ_db=  0.0029425423453989007 a=  0.10473905229747608 b=  0.8667274071746273
037362, 0.2866850877590892, 0.2894902929297895, 0.29228275268186776, 0.29506252481802125, 0.29782966687880813, 0.3005842361438364, 0.30332628963294705, 0.30605588410739243, 0.3087730760710088, 0.3114779217713836, 0.314170477201018, 0.3168507980984831, 0.3195189399495721, 0.3221749579884463, 0.3248189071987765, 0.32745084231487875, 0.3300708178228454, 0.3326788879616708, 0.3352751067243716, 0.3378595278591027, 0.3404322048702676, 0.34299319101962356, 0.34554253932738227, 0.3480803025733053, 0.35060653329779434]
# Zmiana MSE [3.9564939138283473, 3.9208823910228086, 3.8855931365212517, 3.8506232339361572, 3.8159697932720325, 3.781629950686596, 3.747600868254077, 3.7138797337306997, 3.680463760322272, 3.647350186453864, 3.614536275541607, 3.5820193157665114, 3.5497966198503725, 3.5178655248336765, 3.4862233918555368, 3.454867605935606, 3.423795575757963, 3.393004733456969, 3.3624925344050522, 3.332256457002408, 3.3022940024686034, 3.2726026946360895, 3.2431800797455463, 3.2140237262431084, 3.1851312245794112, 3.15650018701046, 3.1281282474002987, 3.10001306102548, 3.0721523043812686, 3.044543674989644, 3.0171848912089976, 2.9900736920455886, 2.9632078369666828, 2.9365851057153916, 2.910203298127172, 2.884060233948024, 2.8581537526542897, 2.8324817132741025, 2.807041994210468, 2.7818324930659126, 2.756851126468743, 2.732095829900871, 2.707564557527198, 2.6832552820265367, 2.659165994424081, 2.63529470392536, 2.611639437751734, 2.588198240977338, 2.564969176367545, 2.541950324218849, 2.5191397822002273, 2.49653566519592, 2.4741361051496407, 2.451939250910207, 2.429943268078538, 2.408146338856067, 2.3865466618945117, 2.365142452147006, 2.343931940720579, 2.32291337472997, 2.3020850171527645, 2.281445146685846, 2.2609920576031337, 2.2407240596146307, 2.2206394777267247, 2.2007366521037635, 2.1810139379308877, 2.1614697052780905, 2.1421023389655196, 2.122910238430001, 2.1038918175927592, 2.0850455047283316, 2.0663697423346963, 2.0478629870045366, 2.029523709297703, 2.0113503936148134, 1.9933415380719914, 1.9754956543767677, 1.9578112677050572, 1.9402869165792995, 1.9229211527476593, 1.9057125410643596, 1.8886596593710556, 1.871761098379325, 1.8550154615541816, 1.8384213649986798, 1.8219774373395339, 1.8056823196137874, 1.7895346651565094, 1.7735331394894922, 1.7576764202109818, 1.74196319688638, 1.726392170939947, 1.7109620555474927, 1.6956715755300202, 1.6805194672483477, 1.6655044784986774, 1.650625368409109, 1.6358809073370917, 1.6212698767678027]

# %%
#dane prawdziwe
plt.scatter(x, y, label="ground truth", color="black")
#dane przewidywane
plt.xlabel('Waga dziecka')
plt.ylabel('IQ dziecka')

#plt.scatter(x, y_predicted, label="predicted", color="red" )
plt.plot(x, y_predicted, color="red", label="prediction")

plt.title("IQ dziecka vs Waga dziecka")
plt.legend()
plt.show()

# %%
#dane prawdziwe
plt.xlabel('a')
plt.plot(listaa[:15000])
plt.show()

plt.xlabel('b')
plt.plot(listab[:15000])
plt.show()

plt.xlabel('MSE')
plt.plot(listaMSE[:15000])
plt.show()

# %%
print(listaa[-1])
print(listab[-1])
# Out:
# 0.10473647743800558
# 0.8667303497169727

# %%
